# %%
import pandas as pd

url='http://www.stockq.org/market/asia.php'
table=pd.read_html(url)[7]
table
# Out:
#                          0                       1                       2  \
# 0   亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)
# 1                       股市                      指數                      漲跌
# 2                      紐西蘭                11805.14                   58.19
# 3                     澳洲股市                 7180.50                  -15.80
# 4                    日經225                23864.56                 -218.95
# 5                     東證一部                 1734.97                   -9.19
# 6                     東證二部                 7368.83                  -44.63
# 7                   JASDAQ                  176.31                    0.09
# 8                     韓國股市                 2239.76                  -22.88
# 9                     台灣加權                12118.71                   28.42
# 10                    台灣店頭                  150.37                    0.00
# 11                    上海綜合                 3061.01                  -34.77
# 12                    上海A股                 3207.50                  -36.32
# 13                    上海B股                  257.30                   -3.38
# 14                    深圳A股                 1892.16                  -22.15
# 15                    深圳B股                  985.69                  -16.38
# 16                   滬深300                 4126.55                  -59.28
# 17                    深證成指                10961.43                 -154.46
# 18                    中小板指                 7147.36                  -89.88
# 19                    創業板指                 1968.50                  -13.68
# 20                    香港恆生                28082.00                 -713.91
# 21                    香港國企                11039.68                 -291.81
# 22                    香港紅籌                 4452.21                 -123.82
# 23                   香港創業板                   80.79                   -0.92
# 24                     新加坡                 3235.91                  -44.18
# 25                     菲律賓                 7476.83                  -75.77
# 26                    馬來西亞                 1589.17                    0.29
# 27                    越南股市                  983.85                    5.22
# 28                    泰國股市                 1584.10                   -5.01
# 29                    印尼股市                 6246.83                    1.79
# 30                    印度股市                41422.15                 -106.76
#
#                          3                       4                       5  \
# 0   亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)
# 1                       比例                      最高                      最低
# 2                    0.50%                11805.14                11746.95
# 3                   -0.22%                 7196.30                 7156.50
# 4                   -0.91%                24081.75                23843.48
# 5                   -0.53%                 1744.46                 1732.15
# 6                   -0.60%                 7402.57                 7344.35
# 7                    0.05%                  176.34                  175.62
# 8                   -1.01%                 2266.31                 2238.25
# 9                    0.24%                12151.42                12101.55
# 10                   0.00%                  150.61                  149.96
# 11                  -1.12%                 3085.79                 3052.60
# 12                  -1.12%                 3233.33                 3198.57
# 13                  -1.30%                  260.44                  257.02
# 14                  -1.16%                 1909.43                 1890.23
# 15                  -1.63%                 1002.53                  984.53
# 16                  -1.42%                 4165.02                 4114.36
# 17                  -1.39%                11078.04                10948.58
# 18                  -1.24%                 7224.42                 7138.94
# 19                  -0.69%                 1987.66                 1959.44
# 20                  -2.48%                28441.00                28038.00
# 21                  -2.58%                11227.52                11027.55
# 22                  -2.71%                 4538.41                 4448.03
# 23                  -1.13%                   81.82                   80.41
# 24                  -1.35%                 3275.15                 3232.99
# 25                  -1.00%                 7586.59                 7442.13
# 26                   0.02%                 1592.59                 1588.34
# 27                   0.53%                  984.92                  978.82
# 28                  -0.32%                 1587.85                 1579.90
# 29                   0.03%                 6257.89                 6226.06
# 30                  -0.26%                41532.59                41301.63
#
#                          6                       7                       8
# 0   亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)
# 1                       開盤                    今年表現                    當地時間
# 2                 11746.95                   2.73%                   17:46
# 3                    5.56%                   16:45                     NaN
# 4                 24072.81                   0.88%                   15:00
# 5                    0.79%                   15:00                     NaN
# 6                  7401.13                   1.43%                   15:00
# 7                    1.28%                   15:00                     NaN
# 8                    1.92%                   15:24                     NaN
# 9                    1.01%                   01/20                     NaN
# 10                   0.68%                   13:33                     NaN
# 11                   0.36%                   14:23                     NaN
# 12                   0.36%                   14:23                     NaN
# 13                  260.44                   0.19%                   14:23
# 14                 1909.43                   4.99%                   14:08
# 15                 1002.53                   2.50%                   14:08
# 16                 4165.02                   0.73%                   14:23
# 17                   5.09%                   13:53                     NaN
# 18                 7203.73                   7.76%                   14:08
# 19                 1979.37                   9.48%                   13:53
# 20                  -0.84%                   14:23                     NaN
# 21                  -1.65%                   14:08                     NaN
# 22                  -1.62%                   14:08                     NaN
# 23                   81.65                   3.11%                   14:24
# 24                   0.42%                   14:08                     NaN
# 25                  -4.33%                   14:08                     NaN
# 26                   0.03%                   14:23                     NaN
# 27                   2.38%                   13:22                     NaN
# 28                   0.27%                   12:30                     NaN
# 29                  -0.84%                   12:00                     NaN
# 30                   0.41%                   11:53                     NaN

# %%
import pandas as pd

url='http://www.stockq.org/market/asia.php'
table=pd.read_html(url)[7]
table
# Out:
#                          0                       1                       2  \
# 0   亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)
# 1                       股市                      指數                      漲跌
# 2                      紐西蘭                11805.14                   58.19
# 3                     澳洲股市                 7180.50                  -15.80
# 4                    日經225                23864.56                 -218.95
# 5                     東證一部                 1734.97                   -9.19
# 6                     東證二部                 7368.83                  -44.63
# 7                   JASDAQ                  176.31                    0.09
# 8                     韓國股市                 2239.76                  -22.88
# 9                     台灣加權                12118.71                   28.42
# 10                    台灣店頭                  150.37                    0.00
# 11                    上海綜合                 3061.01                  -34.77
# 12                    上海A股                 3207.50                  -36.32
# 13                    上海B股                  257.30                   -3.38
# 14                    深圳A股                 1892.16                  -22.15
# 15                    深圳B股                  985.69                  -16.38
# 16                   滬深300                 4126.55                  -59.28
# 17                    深證成指                10961.43                 -154.46
# 18                    中小板指                 7147.36                  -89.88
# 19                    創業板指                 1968.50                  -13.68
# 20                    香港恆生                28082.00                 -713.91
# 21                    香港國企                11039.68                 -291.81
# 22                    香港紅籌                 4452.21                 -123.82
# 23                   香港創業板                   80.79                   -0.92
# 24                     新加坡                 3235.91                  -44.18
# 25                     菲律賓                 7476.83                  -75.77
# 26                    馬來西亞                 1589.17                    0.29
# 27                    越南股市                  983.85                    5.22
# 28                    泰國股市                 1584.10                   -5.01
# 29                    印尼股市                 6246.83                    1.79
# 30                    印度股市                41422.15                 -106.76
#
#                          3                       4                       5  \
# 0   亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)
# 1                       比例                      最高                      最低
# 2                    0.50%                11805.14                11746.95
# 3                   -0.22%                 7196.30                 7156.50
# 4                   -0.91%                24081.75                23843.48
# 5                   -0.53%                 1744.46                 1732.15
# 6                   -0.60%                 7402.57                 7344.35
# 7                    0.05%                  176.34                  175.62
# 8                   -1.01%                 2266.31                 2238.25
# 9                    0.24%                12151.42                12101.55
# 10                   0.00%                  150.61                  149.96
# 11                  -1.12%                 3085.79                 3052.60
# 12                  -1.12%                 3233.33                 3198.57
# 13                  -1.30%                  260.44                  257.02
# 14                  -1.16%                 1909.43                 1890.23
# 15                  -1.63%                 1002.53                  984.53
# 16                  -1.42%                 4165.02                 4114.36
# 17                  -1.39%                11078.04                10948.58
# 18                  -1.24%                 7224.42                 7138.94
# 19                  -0.69%                 1987.66                 1959.44
# 20                  -2.48%                28441.00                28038.00
# 21                  -2.58%                11227.52                11027.55
# 22                  -2.71%                 4538.41                 4448.03
# 23                  -1.13%                   81.82                   80.41
# 24                  -1.35%                 3275.15                 3232.99
# 25                  -1.00%                 7586.59                 7442.13
# 26                   0.02%                 1592.59                 1588.34
# 27                   0.53%                  984.92                  978.82
# 28                  -0.32%                 1587.85                 1579.90
# 29                   0.03%                 6257.89                 6226.06
# 30                  -0.26%                41532.59                41301.63
#
#                          6                       7                       8
# 0   亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)  亞洲股市行情 (Asian Markets)
# 1                       開盤                    今年表現                    當地時間
# 2                 11746.95                   2.73%                   17:46
# 3                    5.56%                   16:45                     NaN
# 4                 24072.81                   0.88%                   15:00
# 5                    0.79%                   15:00                     NaN
# 6                  7401.13                   1.43%                   15:00
# 7                    1.28%                   15:00                     NaN
# 8                    1.92%                   15:24                     NaN
# 9                    1.01%                   01/20                     NaN
# 10                   0.68%                   13:33                     NaN
# 11                   0.36%                   14:23                     NaN
# 12                   0.36%                   14:23                     NaN
# 13                  260.44                   0.19%                   14:23
# 14                 1909.43                   4.99%                   14:08
# 15                 1002.53                   2.50%                   14:08
# 16                 4165.02                   0.73%                   14:23
# 17                   5.09%                   13:53                     NaN
# 18                 7203.73                   7.76%                   14:08
# 19                 1979.37                   9.48%                   13:53
# 20                  -0.84%                   14:23                     NaN
# 21                  -1.65%                   14:08                     NaN
# 22                  -1.62%                   14:08                     NaN
# 23                   81.65                   3.11%                   14:24
# 24                   0.42%                   14:08                     NaN
# 25                  -4.33%                   14:08                     NaN
# 26                   0.03%                   14:23                     NaN
# 27                   2.38%                   13:22                     NaN
# 28                   0.27%                   12:30                     NaN
# 29                  -0.84%                   12:00                     NaN
# 30                   0.41%                   11:53                     NaN

# %%
#!/usr/bin/python
import sqlite3 as lite
import sys

con = None

try:
    con = lite.connect('test.db')
    cur = con.cursor()
    cur.execute('SELECT SQLITE_VERSION()')
    data = cur.fetchone()
    print("SQLite version: %s" % data)
except lite.Error as e:
    print
    "Error %s:" % e.args[0]
    sys.exit(1)
finally:
    if con:
        con.close()
# Out:
# SQLite version: 3.30.1

# %%
def generate_sql():
	conn = lite.connect('test.db')
	cursor = conn.cursor()

	sql = 'CREATE TABLE IF NOT EXISTS listed_company (serial_number INT(30) NOT NULL,stock_code INT(30) ,stock_abbre VARCHAR(30) ,company_name VARCHAR(30) ,province VARCHAR(30) ,city VARCHAR(30) ,main_bussiness_income VARCHAR(30) ,net_profit VARCHAR(30) ,employees INT(30) ,listing_date DATETIME(0) ,zhaogushu VARCHAR(30) ,financial_report VARCHAR(30) , industry_classification VARCHAR(255) ,industry_type VARCHAR(255) ,main_business VARCHAR(255) ,PRIMARY KEY (serial_number))'
    # listed_company是要在wade数据库中建立的表，用于存放数据
    
	cursor.execute(sql)
	conn.close()
	
generate_sql()

# %%
from sqlalchemy import create_engine

def write_to_sql(tbl, db = 'test'):
    engine = create_engine('sqlite:///test.db',echo=True)
    # db = 'wade'表示存储到wade这个数据库中,root后面的*是密码
    try:
    	tbl.to_sql('listed_company',con = engine,if_exists='append',index=False)
    	# 因为要循环网页不断数据库写入内容，所以if_exists选择append，同时该表要有表头，parse_one_page（）方法中df.rename已设置
    except Exception as e:
    	print(e)

# %%
write_to_sql(table)
# Out:
# 2020-01-21 14:51:00,324 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-01-21 14:51:00,325 INFO sqlalchemy.engine.base.Engine ()
# 2020-01-21 14:51:00,326 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-01-21 14:51:00,327 INFO sqlalchemy.engine.base.Engine ()
# 2020-01-21 14:51:00,327 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("listed_company")
# 2020-01-21 14:51:00,328 INFO sqlalchemy.engine.base.Engine ()
# 2020-01-21 14:51:00,328 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("listed_company")
# 2020-01-21 14:51:00,329 INFO sqlalchemy.engine.base.Engine ()
# 2020-01-21 14:51:00,331 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE listed_company (
# 	"0" TEXT,
# 	"1" TEXT,
# 	"2" TEXT,
# 	"3" TEXT,
# 	"4" TEXT,
# 	"5" TEXT,
# 	"6" TEXT,
# 	"7" TEXT,
# 	"8" TEXT
# )
#
#
# 2020-01-21 14:51:00,331 INFO sqlalchemy.engine.base.Engine ()
# 2020-01-21 14:51:00,566 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-01-21 14:51:00,571 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-01-21 14:51:00,575 INFO sqlalchemy.engine.base.Engine INSERT INTO listed_company ("0", "1", "2", "3", "4", "5", "6", "7", "8") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-01-21 14:51:00,577 INFO sqlalchemy.engine.base.Engine (('亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)', '亞洲股市行情 (Asian Markets)'), ('股市', '指數', '漲跌', '比例', '最高', '最低', '開盤', '今年表現', '當地時間'), ('紐西蘭', '11805.14', '58.19', '0.50%', '11805.14', '11746.95', '11746.95', '2.73%', '17:46'), ('澳洲股市', '7180.50', '-15.80', '-0.22%', '7196.30', '7156.50', '5.56%', '16:45', None), ('日經225', '23864.56', '-218.95', '-0.91%', '24081.75', '23843.48', '24072.81', '0.88%', '15:00'), ('東證一部', '1734.97', '-9.19', '-0.53%', '1744.46', '1732.15', '0.79%', '15:00', None), ('東證二部', '7368.83', '-44.63', '-0.60%', '7402.57', '7344.35', '7401.13', '1.43%', '15:00'), ('JASDAQ', '176.31', '0.09', '0.05%', '176.34', '175.62', '1.28%', '15:00', None)  ... displaying 10 of 31 total bound parameter sets ...  ('印尼股市', '6246.83', '1.79', '0.03%', '6257.89', '6226.06', '-0.84%', '12:00', None), ('印度股市', '41422.15', '-106.76', '-0.26%', '41532.59', '41301.63', '0.41%', '11:53', None))
# 2020-01-21 14:51:00,582 INFO sqlalchemy.engine.base.Engine COMMIT
